# %% [markdown]
# Hey guys welcome to `Twitter-Sentiment-Analysis101` with Daniel Phiri

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
# You'll need :
# - A laptop
# - Python 3
# - Curiousity
#
# Chalo!

# %%
# We'll be using these libraries to peform our sentiment analysis, so first we install them
# !pip install tweepy
# !pip install textblob
# Out:
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tweepy
from textblob import TextBlob

# %%
# Adding keys necessary to use Twitter API
consumer_key = 'SmeP1hLtdw6DXNcfl16VgWKxw'
consumer_secret = '346g6Y9JQjf2JaBJMXblokP8PpsNan5XEWYL7DsSug6P9Sg4u9'
access_token = '4088958078-zwhnzzFZOiEM6BILMyflX9wK5qCsjen6OdeQdIQ'
access_token_secret = 'CqWmcRArkdKYbcepDcHK2J4Wt9w0S5UW9ODCavl8Z0pjK'

# %% [markdown]
# These are my keys, if you want to implement this get your keys here : https://apps.twitter.com/app/new

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %%
#We enter our search topic 
tweets = api.search('Virat Kohli', count=20)
#api.search('Topic', count=n) Just incase we want more as default is 10

# %%
# We could play around with python and store these tweets in a csv

# %%
# Go through the tweets to analyse thier sentiment 
for tweet in tweets:
    print(tweet.text)
    
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
# Out:
# RT @LuStaysTru: IMF: zambia is in debt
# EL:
# https://t.co/YsAlu6NXca
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @LuStaysTru: IMF: zambia is in debt
# EL:
# https://t.co/YsAlu6NXca
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @fanmutualsbts: 21.TUNISIA
# 22.BULGARIA
# 23.MEXICO
# 24.EGYPT
# 25.ROMANIA
# 26.SRI LANKA
# 27.GREECE
# 28. UK
# 29. SWEDEN
# 30.BOSINIA &amp; HERZEGOVINA
# 3…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @LuStaysTru: IMF: zambia is in debt
# EL:
# https://t.co/YsAlu6NXca
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# サザエは地声が大きすぎるらしい
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @Glencore: Virtual reality training in Zambia?
#
# Explore this and other stories in our latest Sustainability Report. https://t.co/geJqMUz…
# Sentiment(polarity=0.1875, subjectivity=0.6375)
#
# RT @LuStaysTru: IMF: zambia is in debt
# EL:
# https://t.co/YsAlu6NXca
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# ...

# %% [markdown]
# We ger two properties polarity (-1 to 1) and subjectivity ( 0 to 1)

# %% [markdown]
# Polarity is how negative or positive a tweet is and Subjectivity is to how much of an opinion it is compared to how factual it is.
